# %% [markdown]
# <a href="https://colab.research.google.com/github/GargiMakhe/PythonCodes_Gargi/blob/main/Dice_rolling_simulator(CS24204).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

print("===================================")
print("      DICE ROLLING SIMULATOR")
print("===================================")

while True:
    user_input = input("Do you want to roll the dice? (yes/no): ")

    if user_input.lower() == "yes":
        dice = random.randint(1, 6)
        print("🎲 You rolled:", dice)

    elif user_input.lower() == "no":
        print("Thank you for using the Dice Rolling Simulator!")
        break

    else:
        print("Invalid input! Please type 'yes' or 'no'.")
# Out:
# ...
#       DICE ROLLING SIMULATOR
# ...
# Do you want to roll the dice? (yes/no): yes
# 🎲 You rolled: 1
# Do you want to roll the dice? (yes/no): why
# Invalid input! Please type 'yes' or 'no'.
# Do you want to roll the dice? (yes/no): yes
# 🎲 You rolled: 2
# Do you want to roll the dice? (yes/no): 7
# Invalid input! Please type 'yes' or 'no'.
# Do you want to roll the dice? (yes/no): yes
# 🎲 You rolled: 3
# Do you want to roll the dice? (yes/no): no
# Thank you for using the Dice Rolling Simulator!
